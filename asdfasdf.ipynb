# %%
import pandas as pd
shot_df = pd.read_csv("https://ludis-basketball.s3.amazonaws.com/clean-data/shot_tracker_data.csv")

# %%
shot_df.columns
# Out:
# Index(['Unnamed: 0', 'gameid', 'period', 'clock', 'player_name',
#        'jersey_number', 'event_type', 'x', 'y', 'area', 'shot_distance',
#        'shot_types', 'results', 'date', 'home', 'away', 'home_pts', 'away_pts',
#        'converted_x', 'FULL NAME', 'TEAM', 'POS', 'AGE', 'GP', 'MPG', 'FTA',
#        'FT%', '2PA', '2P%', '3PA', '3P%', 'season'],
#       dtype='object')
